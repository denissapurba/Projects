# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif   
import seaborn as sb
# Out:
# In C:\Users\denis\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\denis\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\denis\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\denis\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# PILIH MODEL 2 (Urban Socio Car Ownership)

# %% [markdown]
# ### Data Definition - Model All

# %%
# Main Data
dcdf = pd.read_excel('ols_complete_noncorr.xlsx')
# X data
Xdcdf=dcdf.drop('y', axis=1)
# y data
ydcdf = dcdf['y']

# %%
# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# %%
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.36
# VIF for x2: 3.93
# VIF for x4: 6.95
# VIF for x5: 5.34
# VIF for x6: 3.48
# VIF for x7: 12.12
# VIF for x8: 4.86
# VIF for x13: 6.67
# VIF for x19: 11.05
# VIF for x20: 8.22
# VIF for x21: 3.88
# VIF for lchd: 7.88
# VIF for lhd3: 3.46
# VIF for lhd4: 6.27

# %%
#Delete X10
Xdcdf=Xdcdf.drop('x7', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.35
# VIF for x2: 3.84
# VIF for x4: 6.69
# VIF for x5: 5.18
# VIF for x6: 3.41
# VIF for x8: 2.82
# VIF for x13: 5.79
# VIF for x20: 7.18
# VIF for x21: 3.64
# VIF for lchd: 5.84
# VIF for lhd3: 3.33
# VIF for lhd4: 5.92

# %%
#Delete lhd1
Xdcdf=Xdcdf.drop('lhd1', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.47
# VIF for x2: 6.03
# VIF for x3: 50.18
# VIF for x4: 27.21
# VIF for x5: 5.76
# VIF for x6: 7.27
# VIF for x7: 15.59
# VIF for x8: 5.76
# VIF for x9: 39.32
# VIF for x11: 21.96
# VIF for x12: 147.98
# VIF for x13: 86.85
# VIF for x14: 79.84
# VIF for x15: 3.0
# VIF for x16: 94.19
# VIF for x17: 149.59
# VIF for x18: 62.07
# VIF for x19: 34.51
# VIF for x20: 31.79
# VIF for x21: 6.14
# VIF for x22: 100.77
# VIF for lchd: 33.32
# VIF for lhd2: 188.38
# VIF for lhd3: 13.96
# VIF for lhd4: 15.28

# %%
#Delete X14
Xdcdf=Xdcdf.drop('x14', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.47
# VIF for x2: 5.89
# VIF for x3: 50.11
# VIF for x4: 27.17
# VIF for x5: 5.67
# VIF for x6: 7.24
# VIF for x7: 15.25
# VIF for x8: 5.49
# VIF for x9: 39.19
# VIF for x11: 21.18
# VIF for x12: 142.98
# VIF for x13: 59.66
# VIF for x15: 2.96
# VIF for x16: 92.35
# VIF for x17: 149.43
# VIF for x18: 61.96
# VIF for x19: 32.9
# VIF for x20: 29.98
# VIF for x21: 5.94
# VIF for x22: 99.32
# VIF for lchd: 32.35
# VIF for lhd2: 179.11
# VIF for lhd3: 13.8
# VIF for lhd4: 15.27

# %%
#Delete X17
Xdcdf=Xdcdf.drop('x17', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.47
# VIF for x2: 5.87
# VIF for x3: 49.3
# VIF for x4: 27.17
# VIF for x5: 5.67
# VIF for x6: 7.13
# VIF for x7: 15.25
# VIF for x8: 5.49
# VIF for x9: 38.07
# VIF for x11: 21.16
# VIF for x12: 27.82
# VIF for x13: 49.23
# VIF for x15: 2.92
# VIF for x16: 25.45
# VIF for x18: 28.22
# VIF for x19: 32.65
# VIF for x20: 29.98
# VIF for x21: 5.94
# VIF for x22: 98.68
# VIF for lchd: 31.31
# VIF for lhd2: 138.93
# VIF for lhd3: 4.91
# VIF for lhd4: 13.04

# %%
#Delete ldh2
Xdcdf=Xdcdf.drop('lhd2', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.45
# VIF for x2: 5.85
# VIF for x3: 49.14
# VIF for x4: 27.05
# VIF for x5: 5.62
# VIF for x6: 7.12
# VIF for x7: 15.25
# VIF for x8: 5.49
# VIF for x9: 36.17
# VIF for x11: 21.02
# VIF for x12: 23.22
# VIF for x13: 22.83
# VIF for x15: 2.92
# VIF for x16: 24.76
# VIF for x18: 28.22
# VIF for x19: 32.39
# VIF for x20: 29.65
# VIF for x21: 5.93
# VIF for x22: 98.65
# VIF for lchd: 15.13
# VIF for lhd3: 4.87
# VIF for lhd4: 10.27

# %%
#Delete x22
Xdcdf=Xdcdf.drop('x22', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.44
# VIF for x2: 5.65
# VIF for x3: 48.01
# VIF for x4: 27.04
# VIF for x5: 5.59
# VIF for x6: 7.01
# VIF for x7: 14.82
# VIF for x8: 5.45
# VIF for x9: 36.09
# VIF for x11: 21.02
# VIF for x12: 22.33
# VIF for x13: 22.59
# VIF for x15: 2.92
# VIF for x16: 22.38
# VIF for x18: 27.92
# VIF for x19: 14.72
# VIF for x20: 11.71
# VIF for x21: 5.86
# VIF for lchd: 15.1
# VIF for lhd3: 4.86
# VIF for lhd4: 10.25

# %%
#Delete x3
Xdcdf=Xdcdf.drop('x3', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.44
# VIF for x2: 4.54
# VIF for x4: 7.31
# VIF for x5: 5.53
# VIF for x6: 6.96
# VIF for x7: 14.69
# VIF for x8: 5.45
# VIF for x9: 35.17
# VIF for x11: 20.29
# VIF for x12: 22.07
# VIF for x13: 22.58
# VIF for x15: 2.88
# VIF for x16: 22.01
# VIF for x18: 27.02
# VIF for x19: 13.09
# VIF for x20: 10.26
# VIF for x21: 5.82
# VIF for lchd: 15.07
# VIF for lhd3: 4.83
# VIF for lhd4: 10.23

# %%
#Delete x9
Xdcdf=Xdcdf.drop('x9', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.43
# VIF for x2: 4.51
# VIF for x4: 7.26
# VIF for x5: 5.47
# VIF for x6: 6.93
# VIF for x7: 13.85
# VIF for x8: 5.37
# VIF for x11: 19.26
# VIF for x12: 21.96
# VIF for x13: 20.21
# VIF for x15: 2.88
# VIF for x16: 20.28
# VIF for x18: 26.09
# VIF for x19: 13.05
# VIF for x20: 10.24
# VIF for x21: 5.71
# VIF for lchd: 13.78
# VIF for lhd3: 4.82
# VIF for lhd4: 10.07

# %%
#Delete ldh4
Xdcdf=Xdcdf.drop('lhd4', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.43
# VIF for x2: 4.49
# VIF for x4: 7.24
# VIF for x5: 5.39
# VIF for x6: 6.93
# VIF for x7: 13.84
# VIF for x8: 5.35
# VIF for x11: 19.21
# VIF for x12: 21.54
# VIF for x13: 19.44
# VIF for x15: 2.88
# VIF for x16: 20.24
# VIF for x18: 20.88
# VIF for x19: 13.04
# VIF for x20: 10.01
# VIF for x21: 5.71
# VIF for lchd: 13.78
# VIF for lhd3: 4.55

# %%
#Delete x15
Xdcdf=Xdcdf.drop('x15', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.43
# VIF for x2: 4.49
# VIF for x4: 7.2
# VIF for x5: 5.34
# VIF for x6: 3.68
# VIF for x7: 13.05
# VIF for x8: 5.23
# VIF for x11: 19.21
# VIF for x12: 21.11
# VIF for x13: 18.44
# VIF for x16: 20.22
# VIF for x18: 20.4
# VIF for x19: 12.35
# VIF for x20: 9.78
# VIF for x21: 5.71
# VIF for lchd: 13.43
# VIF for lhd3: 4.54

# %%
#Delete x11
Xdcdf=Xdcdf.drop('x11', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.41
# VIF for x2: 3.99
# VIF for x4: 7.06
# VIF for x5: 5.31
# VIF for x6: 3.61
# VIF for x7: 12.37
# VIF for x8: 4.91
# VIF for x12: 20.47
# VIF for x13: 17.43
# VIF for x16: 19.56
# VIF for x18: 18.3
# VIF for x19: 12.28
# VIF for x20: 9.73
# VIF for x21: 4.04
# VIF for lchd: 12.09
# VIF for lhd3: 4.21

# %%
#Delete x12
Xdcdf=Xdcdf.drop('x12', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.41
# VIF for x2: 3.92
# VIF for x4: 7.06
# VIF for x5: 5.31
# VIF for x6: 3.61
# VIF for x7: 12.26
# VIF for x8: 4.86
# VIF for x13: 16.62
# VIF for x16: 10.03
# VIF for x18: 17.2
# VIF for x19: 12.11
# VIF for x20: 9.71
# VIF for x21: 4.04
# VIF for lchd: 11.37
# VIF for lhd3: 4.11

# %%
#Delete x18
Xdcdf=Xdcdf.drop('x18', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     310             try:
# --> 311                 self._store_workbook()
#     312             except IOError as e:
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     626         except IOError as e:
# --> 627             raise e
#     628
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     624             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 625                                 allowZip64=self.allow_zip64)
#     626         except IOError as e:
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1206                 try:
# -> 1207                     self.fp = io.open(file, filemode)
# ...

# %%
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')
# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.41
# VIF for x2: 3.92
# VIF for x4: 6.99
# VIF for x5: 5.16
# VIF for x6: 3.6
# VIF for x7: 12.22
# VIF for x8: 4.85
# VIF for x13: 6.92
# VIF for x16: 5.34
# VIF for x19: 11.64
# VIF for x20: 8.91
# VIF for x21: 4.0
# VIF for lchd: 7.74
# VIF for lhd3: 3.72

# %%
#Delete x7
Xdcdf=Xdcdf.drop('x7', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.4
# VIF for x2: 3.91
# VIF for x4: 6.93
# VIF for x5: 5.08
# VIF for x6: 3.55
# VIF for x8: 3.2
# VIF for x13: 6.61
# VIF for x16: 5.3
# VIF for x19: 11.38
# VIF for x20: 8.18
# VIF for x21: 3.73
# VIF for lchd: 7.73
# VIF for lhd3: 3.68

# %%
#Delete x19
Xdcdf=Xdcdf.drop('x19', axis=1)

# Correlation Test (Pearson)
pearsoncorr = Xdcdf.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.2)
pearsoncorr.to_excel('pearsoncorr_model_complete.xlsx')

# VIF Test
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.39
# VIF for x2: 3.85
# VIF for x4: 6.69
# VIF for x5: 4.94
# VIF for x6: 3.54
# VIF for x8: 2.86
# VIF for x13: 6.55
# VIF for x16: 4.78
# VIF for x20: 7.78
# VIF for x21: 3.72
# VIF for lchd: 4.85
# VIF for lhd3: 3.36

# %%
Xdcdf
# Out:
#            x1        x2          x4          x5          x6            x8  \
# 0    2.503057  2.986761  113.538574  143.776136  377.548922  24938.056439
# 1    0.000000  0.500000  135.299000  561.764876  121.333333  99952.287486
# 2    6.685099  4.445140  114.417441  167.733764  219.804254  23468.385374
# 3    0.000000  3.518409  116.344232  374.529870  186.651216  13442.719502
# 4    0.000000  3.218725  147.334649  153.340534  282.290148  15677.427068
# ..        ...       ...         ...         ...         ...           ...
# 174  1.498455  8.467676  154.228102   70.496458  841.727885  50977.432414
# 175  1.699802  5.584761   73.408480  109.072393  493.430844  37113.209853
# 176  3.876616  0.007270   26.461492  480.919684  239.873145  31744.041426
# 177  0.000000  0.998659   85.139375  134.119018  104.273279  21197.989012
# 178  1.059747  1.687268   70.502357  297.347603  327.285854  15281.452765
#
#       x13  x16   x20   x21  lchd  lhd3
# 0     776  637  12.7  19.1   421   229
# ...

# %%
Xdc=Xdcdf.values

# %%
X = sm.add_constant(Xdc)
est01 = sm.OLS(ydc, X)
est012 = est01.fit()
print(est012.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.685
# Method:                 Least Squares   F-statistic:                     33.28
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           4.70e-38
# Time:                        18:14:35   Log-Likelihood:                -517.25
# No. Observations:                 179   AIC:                             1060.
# Df Residuals:                     166   BIC:                             1102.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.7956      2.523      9.827      0.000      19.814      29.777
# ...

# %% [markdown]
# ### Data Definition - Model 02 (Urban, Socioeconomics, Car Ownership)

# %%
# Main Data
dcdf = pd.read_excel('ols_complete_mod02.xlsx')

# X data
Xdcdf=dcdf.drop('y', axis=1)


# y data
ydcdf = dcdf['y']
ydc=ydcdf.values

# %%
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.35
# VIF for x2: 4.05
# VIF for x4: 6.58
# VIF for x5: 5.29
# VIF for x6: 6.48
# VIF for x7: 11.97
# VIF for x8: 5.0
# VIF for x11: 12.61
# VIF for x12: 5.86
# VIF for x15: 2.49
# VIF for x18: 13.6
# VIF for lchd: 8.73
# VIF for lhd3: 4.28
# VIF for lhd4: 9.36

# %%
Xdcdf
# Out:
#            x1        x2          x4          x5          x6        x7  \
# 0    2.503057  2.986761  113.538574  143.776136  377.548922  87817.89
# 1    0.000000  0.500000  135.299000  561.764876  121.333333  72729.51
# 2    6.685099  4.445140  114.417441  167.733764  219.804254  57563.19
# 3    0.000000  3.518409  116.344232  374.529870  186.651216  97145.17
# 4    0.000000  3.218725  147.334649  153.340534  282.290148  27632.56
# ..        ...       ...         ...         ...         ...       ...
# 174  1.498455  8.467676  154.228102   70.496458  841.727885  77807.66
# 175  1.699802  5.584761   73.408480  109.072393  493.430844  76969.57
# 176  3.876616  0.007270   26.461492  480.919684  239.873145  85493.32
# 177  0.000000  0.998659   85.139375  134.119018  104.273279  92467.09
# 178  1.059747  1.687268   70.502357  297.347603  327.285854  67487.16
#
#                x8     x11   x12    x15  x18  lchd  lhd3  lhd4
# 0    24938.056439  167188  1293   7135  644   421   229   367
# ...

# %%
Xdc=Xdcdf.values

# %%
X = sm.add_constant(Xdc)
est02 = sm.OLS(ydc, X)
est022 = est02.fit()
print(est022.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.744
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     34.00
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           3.05e-41
# Time:                        15:34:48   Log-Likelihood:                -505.07
# No. Observations:                 179   AIC:                             1040.
# Df Residuals:                     164   BIC:                             1088.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.7313      2.027      9.243      0.000      14.730      22.733
# ...

# %% [markdown]
# ### Data Definition - Model 03 (Urban, Socioeconomics, Car Ownership, Commuting)

# %%
# Main Data
dcdf = pd.read_excel('ols_complete_mod03.xlsx')

# X data
Xdcdf=dcdf.drop('y', axis=1)


# y data
ydcdf = dcdf['y']
ydc=ydcdf.values

# %%
for i in range(len(Xdcdf.columns[:])):
    v=vif(np.matrix(Xdcdf[:]),i)
    print("VIF for {}: {}".format(Xdcdf.columns[i],round(v,2)))
# Out:
# VIF for x1: 1.43
# VIF for x2: 5.95
# VIF for x3: 49.72
# VIF for x4: 27.09
# VIF for x5: 5.7
# VIF for x6: 6.86
# VIF for x7: 15.36
# VIF for x8: 5.54
# VIF for x9: 33.56
# VIF for x10: inf
# VIF for x11: 20.49
# VIF for x12: 81.36
# VIF for x13: 44.44
# VIF for x14: 73.65
# VIF for x15: 2.87
# VIF for x16: inf
# VIF for x17: inf
# VIF for x18: inf
# VIF for S0801_C01_002E: 32.83
# VIF for S0801_C01_009E: 30.22
# VIF for S0801_C01_013E: 5.96
# VIF for S0801_C01_046E: 99.37

# %%
Xdcdf

# %%
Xdc=Xdcdf.values
X = sm.add_constant(Xdc)
est03 = sm.OLS(ydc, X)
est032 = est03.fit()
print(est032.summary())

# %% [markdown]
# ### Data Definition - Model 04 (Urban, Socioeconomics, Commuting)

# %%
# Main Data
dcdf = pd.read_excel('ols_complete_mod02.xlsx')

# X data
Xdcdf=dcdf.drop('y', axis=1)
Xdc=Xdcdf.values

# y data
ydcdf = dcdf['y']
ydc=ydcdf.values

X = sm.add_constant(Xdc)
est04 = sm.OLS(ydc, X)
est042 = est04.fit()
print(est042.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.744
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     34.00
# Date:                Thu, 03 Dec 2020   Prob (F-statistic):           3.05e-41
# Time:                        04:50:17   Log-Likelihood:                -505.07
# No. Observations:                 179   AIC:                             1040.
# Df Residuals:                     164   BIC:                             1088.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.7313      2.027      9.243      0.000      14.730      22.733
# ...

# %%
Xdcdf
# Out:
#            x1        x2          x4          x5          x6        x7  \
# 0    2.503057  2.986761  113.538574  143.776136  377.548922  87817.89
# 1    0.000000  0.500000  135.299000  561.764876  121.333333  72729.51
# 2    6.685099  4.445140  114.417441  167.733764  219.804254  57563.19
# 3    0.000000  3.518409  116.344232  374.529870  186.651216  97145.17
# 4    0.000000  3.218725  147.334649  153.340534  282.290148  27632.56
# ..        ...       ...         ...         ...         ...       ...
# 174  1.498455  8.467676  154.228102   70.496458  841.727885  77807.66
# 175  1.699802  5.584761   73.408480  109.072393  493.430844  76969.57
# 176  3.876616  0.007270   26.461492  480.919684  239.873145  85493.32
# 177  0.000000  0.998659   85.139375  134.119018  104.273279  92467.09
# 178  1.059747  1.687268   70.502357  297.347603  327.285854  67487.16
#
#                x8     x11   x12    x15  x18  lchd  lhd3  lhd4
# 0    24938.056439  167188  1293   7135  644   421   229   367
# ...

# %% [markdown]
# ### Data Definition - Model 05 (Urban, Socioeconomics, Life Cycle)

# %%
# Main Data
dcdf = pd.read_excel('ols_complete_mod05.xlsx')

# X data
Xdcdf=dcdf.drop('y', axis=1)
Xdc=Xdcdf.values

# y data
ydcdf = dcdf['y']
ydc=ydcdf.values

X = sm.add_constant(Xdc)
est05 = sm.OLS(ydc, X)
est052 = est05.fit()
print(est052.summary())
